# %% [markdown]
# Cognitive Fatigue Analysis

# %% [markdown]
# Comparison for feature extraction:
# - grands of none dementia T1 runs 1 vs grands of none dementia T1 runs 2

# %%
from cf_libs import *
from cf_helper import *
import sys
sys.path.insert(1, '/Users/joshuaighalo/Documents/GitHub/eegDementia')
from eeg_helper import*
import params as cfg

# %% [markdown]
# <Functions>

# %% [markdown]
# <b>Import Scans<b>

# %%
grpScanDir = '/Users/joshuaighalo/Documents/GitHub/eegDementia/groupingScans/database/'
scans_1 = pd.read_csv(grpScanDir + 'groupFirstScans.csv')
scans_2 = pd.read_csv(grpScanDir + 'groupSecondScans.csv')
dataPath = '/Users/joshuaighalo/Downloads/brainNet_datasets/laurel_place/cleaned_dataset'
imgPath = '/Users/joshuaighalo/Documents/GitHub/eegDementia/mlOPS/fatigueIndex/images/exploreFeatures'

# %%
noB_1 = list((scans_1['Baseline No Dementia'].values)[~pd.isnull(scans_1['Baseline No Dementia'].values)])
noB_2 = list((scans_2['Baseline No Dementia'].values)[~pd.isnull(scans_2['Baseline No Dementia'].values)])
no6_1 = list((scans_1['4-months No Dementia'].values)[~pd.isnull(scans_1['4-months No Dementia'].values)])
no6_2 = list((scans_2['4-months No Dementia'].values)[~pd.isnull(scans_2['4-months No Dementia'].values)])
no12_1 = list((scans_1['8-months No Dementia'].values)[~pd.isnull(scans_1['8-months No Dementia'].values)])
no12_2 = list((scans_2['8-months No Dementia'].values)[~pd.isnull(scans_2['8-months No Dementia'].values)])
mildB_1 = list((scans_1['Baseline Mild Dementia'].values)[~pd.isnull(scans_1['Baseline Mild Dementia'].values)])
mildB_2 = list((scans_2['Baseline Mild Dementia'].values)[~pd.isnull(scans_2['Baseline Mild Dementia'].values)])
mild6_1 = list((scans_1['4-months Mild Dementia'].values)[~pd.isnull(scans_1['4-months Mild Dementia'].values)])
mild6_2 = list((scans_2['4-months Mild Dementia'].values)[~pd.isnull(scans_2['4-months Mild Dementia'].values)])
mild12_1 = list((scans_1['8-months Mild Dementia'].values)[~pd.isnull(scans_1['8-months Mild Dementia'].values)])
mild12_2 = list((scans_2['8-months Mild Dementia'].values)[~pd.isnull(scans_2['8-months Mild Dementia'].values)])
modB_1 = list((scans_1['Baseline Moderate Dementia'].values)[~pd.isnull(scans_1['Baseline Moderate Dementia'].values)])
modB_2 = list((scans_2['Baseline Moderate Dementia'].values)[~pd.isnull(scans_2['Baseline Moderate Dementia'].values)])
mod6_1 = list((scans_1['4-months Moderate Dementia'].values)[~pd.isnull(scans_1['4-months Moderate Dementia'].values)])
mod6_2 = list((scans_2['4-months Moderate Dementia'].values)[~pd.isnull(scans_2['4-months Moderate Dementia'].values)])
mod12_1 = list((scans_1['8-months Moderate Dementia'].values)[~pd.isnull(scans_1['8-months Moderate Dementia'].values)])
mod12_2 = list((scans_2['8-months Moderate Dementia'].values)[~pd.isnull(scans_2['8-months Moderate Dementia'].values)])
sevB_1 = list((scans_1['Baseline Severe Dementia'].values)[~pd.isnull(scans_1['Baseline Severe Dementia'].values)])
sevB_2 = list((scans_2['Baseline Severe Dementia'].values)[~pd.isnull(scans_2['Baseline Severe Dementia'].values)])
sev6_1 = list((scans_1['4-months Severe Dementia'].values)[~pd.isnull(scans_1['4-months Severe Dementia'].values)])
sev6_2 = list((scans_2['4-months Severe Dementia'].values)[~pd.isnull(scans_2['4-months Severe Dementia'].values)])
sev12_1 = list((scans_1['8-months Severe Dementia'].values)[~pd.isnull(scans_1['8-months Severe Dementia'].values)])
sev12_2 = list((scans_2['8-months Severe Dementia'].values)[~pd.isnull(scans_2['8-months Severe Dementia'].values)])
mildmodB_1 = mildB_1 + modB_1
mildmodB_2 = mildB_2 + modB_2
mildmod6_1 = mild6_1 + mod6_1
mildmod6_2 = mild6_2 + mod6_2
mildmod12_1 = mild12_1 + mod12_1
mildmod12_2 = mild12_2 + mod12_2

# %% [markdown]
# <b>Remove Scans with Enormous Artifacts<b>

# %%
print('No Dementia | Baseline | Run 1: ',len(noB_1))
qBND_1 = removeBadRawEEGs(noB_1,1.0,dataPath)
print('No Dementia | Baseline | Run 2: ',len(noB_2))
qBND_2 = removeBadRawEEGs(noB_2,1.0,dataPath)
qBND = duplicateBetweenLists(qBND_1,qBND_2)
BND_1,BND_2 = qBND[:,0],qBND[:,1]

print('No Dementia | 6 months | Run 1: ',len(no6_1))
q6ND_1 = removeBadRawEEGs(no6_1,1.0,dataPath)
print('No Dementia | 6 months | Run 2: ',len(no6_2))
q6ND_2 = removeBadRawEEGs(no6_2,1.0,dataPath)
q6ND = duplicateBetweenLists(q6ND_1,q6ND_2)
ND6_1,ND6_2 = q6ND[:,0],q6ND[:,1]

print('No Dementia | 12 months | Run 1: ',len(no12_1))
q12ND_1 = removeBadRawEEGs(no12_1,1.0,dataPath)
print('No Dementia | 12 months | Run 2: ',len(no12_2))
q12ND_2 = removeBadRawEEGs(no12_2,1.0,dataPath)
q12ND = duplicateBetweenLists(q12ND_1,q12ND_2)
ND12_1,ND12_2 = q12ND[:,0],q12ND[:,1]
# Out:
# No Dementia | Baseline | Run 1:  14
#                       mse              filename
# 0      3826051.8746914547  0005_1_06052019_1023
# 1      370391.84979512705  0011_1_11122017_1357
# 2       7632381.785626909  0038_1_21032019_1045
# 3      1887968.1615081038  0049_1_25022019_1154
# 4      255965.29928580904  0066_1_26042019_0944
# 5      110696.37572122403  0073_1_13032019_1057
# 6       992298.3746315724  0074_1_09062017_1048
# 7      180101.78160392694  0075_1_22022019_1136
# 8      3804125.9861565433  0102_1_24042019_1042
# 9       1903202.298737533  0108_1_21032019_1014
# 10      7859635.610293617  0114_1_17042019_1143
# 11  1.241108381955667e+55  0402_1_25022019_1438
# 12       3564786.57439335  0403_1_06032019_1108
# 13      3780759.305345673  0408_1_01052019_1006
#       outlier filenames
# 0  0402_1_25022019_1438
# No Dementia | Baseline | Run 2:  12
#                       mse              filename
# 0   2.782663662659141e+44  0005_2_06052019_1029
# ...

# %%
print('Mild-Moderate Dementia | Baseline | Run 1: ',len(mildmodB_1))
qBMMD_1 = removeBadRawEEGs(mildmodB_1,1.0,dataPath)
print('Mild-Moderate Dementia | Baseline | Run 2: ',len(mildmodB_2))
qBMMD_2 = removeBadRawEEGs(mildmodB_2,1.0,dataPath)
qBMMD = duplicateBetweenLists(qBMMD_1,qBMMD_2)
BMMD_1,BMMD_2 = qBMMD[:,0],qBMMD[:,1]

print('Mild-Moderate Dementia | 6 months | Run 1: ',len(mildmod6_1))
q6MMD_1 = removeBadRawEEGs(mildmod6_1,1.0,dataPath)
print('Mild-Moderate Dementia | 6 months | Run 2: ',len(mildmod6_2))
q6MMD_2 = removeBadRawEEGs(mildmod6_2,1.0,dataPath)
q6MMD_2 = np.delete(q6MMD_2,3,0)                                        #   remove item of index 3 from q6MMD_2 as its an outlier
q6MMD = duplicateBetweenLists(q6MMD_1,q6MMD_2)
MMD6_1,MMD6_2 = q6MMD[:,0],q6MMD[:,1]

print('Mild-Moderate Dementia | 12 months | Run 1: ',len(mildmod12_1))
q12MMD_1 = removeBadRawEEGs(mildmod12_1,1.0,dataPath)
print('Mild-Moderate Dementia | 12 months | Run 2: ',len(mildmod12_2))
q12MMD_2 = removeBadRawEEGs(mildmod12_2,1.0,dataPath)
q12MMD = duplicateBetweenLists(q12MMD_1,q12MMD_2)
MMD12_1,MMD12_2 = q12MMD[:,0],q12MMD[:,1]
# Out:
# Mild-Moderate Dementia | Baseline | Run 1:  17
#                    mse              filename
# 0   16389910.115973337  0045_1_01052019_1040
# 1     4452592.51500049  0085_1_25022019_1113
# 2   21826298.250704248  0091_1_24042019_1121
# 3   3554608.6092240545  0093_1_08042019_1205
# 4    8090813.761488285  0111_1_19032019_1032
# 5   1814101.9278725358  0405_1_12042019_1129
# 6    9704062.407601958  0003_1_15042019_1133
# 7     2800264.01950586  0007_1_06052019_1001
# 8   1606279.4006273742  0024_1_06032019_1406
# 9   2315888.0154723777  0028_1_17042019_1103
# 10   7611994.875176425  0048_1_01052019_1110
# 11  1124714.7592873808  0087_1_13032019_1021
# 12  7178652.5142326085  0104_1_08042019_1132
# 13  17659494.299921066  0115_1_04032019_1445
# 14  11007.632016200507  0120_1_24042019_1005
# 15   13843320.04598716  0127_1_10042019_1033
# 16  7112832.3937957175  0404_1_06032019_1451
# Empty DataFrame
# Columns: [outlier filenames]
# Index: []
# ...

# %%
print('Severe Dementia | Baseline | Run 1: ',len(sevB_1))
qBSD_1 = removeBadRawEEGs(sevB_1,1.0,dataPath)
print('Severe Dementia | Baseline | Run 2: ',len(sevB_2))
qBSD_2 = removeBadRawEEGs(sevB_2,1.0,dataPath)
qBSD = duplicateBetweenLists(qBSD_1,qBSD_2)
BSD_1,BSD_2 = qBSD[:,0],qBSD[:,1]

print('Severe Dementia | 6 months | Run 1: ',len(sev6_1))
q6SD_1 = removeBadRawEEGs(sev6_1,1.0,dataPath)
print('Severe Dementia | 6 months | Run 2: ',len(sev6_2))
q6SD_2 = removeBadRawEEGs(sev6_2,1.0,dataPath)
q6SD = duplicateBetweenLists(q6SD_1,q6SD_2)
SD6_1,SD6_2 = q6SD[:,0],q6SD[:,1]

print('Severe Dementia | 12 months | Run 1: ',len(sev12_1))
q12SD_1 = removeBadRawEEGs(sev12_1,1.0,dataPath)
print('Severe Dementia | 12 months | Run 2: ',len(sev12_2))
q12SD_2 = removeBadRawEEGs(sev12_2,1.0,dataPath)
q12SD = duplicateBetweenLists(q12SD_1,q12SD_2)
SD12_1,SD12_2 = q12SD[:,0],q12SD[:,1]
# Out:
# Severe Dementia | Baseline | Run 1:  16
#                       mse              filename
# 0       3917540.705498974  0002_1_26042019_1008
# 1      10488282.879887482  0006_1_08042019_1105
# 2       22180966.90893786  0008_1_04032019_1111
# 3   5.764456616738804e+67  0014_1_17042019_1029
# 4      2856301492.2538657  0017_1_04032019_1144
# 5       606420071.1263003  0026_1_11032019_1211
# 6       3613463.844401816  0031_1_10042019_1145
# 7       700193.7824310038  0054_1_06052019_1055
# 8      10973079.762116853  0064_1_15042019_1204
# 9      32937521.059646916  0069_1_25022019_1353
# 10      5203325.975807754  0110_1_04032019_1403
# 11       5707617.22960766  0113_1_21032019_1117
# 12      1360297.870128944  0123_1_19032019_1104
# 13      4266023.736886253  0134_1_21032019_1213
# 14     505331.82211160235  0406_1_15042019_1047
# 15      3447537.226536969  0407_1_26042019_1039
#       outlier filenames
# 0  0014_1_17042019_1029
# Severe Dementia | Baseline | Run 2:  15
# ...

# %% [markdown]
# <b>Compute ERPs<b>

# %%
args_1 = {'deviceVersion':1.0,'path':dataPath,'sfreq':cfg.fs,'line':cfg.line,'highPass':0.1,
        'lowPass':10,'stimTriggers':cfg.stimTrig,'clip':75,'channel_names':['Fz','Cz','Pz'],
        'ERPs_GrandAverages':True,'erp_plots':True}

# %%
print('No Dementia | Baseline | Run 1')
erpsBND_1 = pipeline(filenames=BND_1,**args_1)

print('No Dementia | Baseline | Run 2')
erpsBND_2 = pipeline(filenames=BND_2,**args_1)
# Out:
# No Dementia | Baseline | Run 1
# Processing file:  0038_1_21032019_1045
# Processing file:  0049_1_25022019_1154
# Processing file:  0066_1_26042019_0944
# Processing file:  0073_1_13032019_1057
# Processing file:  0074_1_09062017_1048
# Processing file:  0075_1_22022019_1136
# Processing file:  0102_1_24042019_1042
# Processing file:  0108_1_21032019_1014
# Processing file:  0114_1_17042019_1143
# Processing file:  0408_1_01052019_1006
# No Dementia | Baseline | Run 2
# Processing file:  0038_2_21032019_1051
# Processing file:  0049_2_25022019_1202
# Processing file:  0066_2_26042019_0951
# Processing file:  0073_2_13032019_1104
# Processing file:  0074_2_09062017_1055
# Processing file:  0075_2_22022019_1147
# Processing file:  0102_2_24042019_1049
# Processing file:  0108_2_21032019_1022
# Processing file:  0114_2_17042019_1150
# Processing file:  0408_2_01052019_1013

# %%
print('No Dementia | 6-months | Run 1')
erps6ND_1 = pipeline(filenames=ND6_1,**args_1)

print('No Dementia | 6-months | Run 2')
erps6ND_2 = pipeline(filenames=ND6_2,**args_1)
# Out:
# No Dementia | 6-months | Run 1
# Processing file:  0005_1_03092019_1155
# Processing file:  0038_1_07082019_1432
# Processing file:  0049_1_16072019_1044
# Processing file:  0066_1_27082019_1141
# Processing file:  0073_1_31072019_1129
# Processing file:  0102_1_20082019_1607
# Processing file:  0108_1_13082019_1105
# Processing file:  0402_1_16072019_1203
# Processing file:  0408_1_04092019_1128
# No Dementia | 6-months | Run 2
# Processing file:  0005_2_03092019_1201
# Processing file:  0038_2_07082019_1438
# Processing file:  0049_2_16072019_1051
# Processing file:  0066_2_27082019_1147
# Processing file:  0073_2_31072019_1136
# Processing file:  0102_2_20082019_1614
# Processing file:  0108_2_13082019_1111
# Processing file:  0402_2_16072019_1209
# Processing file:  0408_2_04092019_1135

# %%
print('No Dementia | 12-months | Run 1')
erps12ND_1 = pipeline(filenames=ND12_1,**args_1)

print('No Dementia | 12-months | Run 2')
erps12ND_2 = pipeline(filenames=ND12_2,**args_1)
# Out:
# No Dementia | 12-months | Run 1
# Processing file:  0011_1_22022019_1357
# Processing file:  0037_1_08052019_1109
# Processing file:  0038_1_05122019_1456
# Processing file:  0049_1_15112019_1203
# Processing file:  0066_1_06122019_1435
# Processing file:  0073_1_06122019_1158
# Processing file:  0102_1_12122019_1108
# Processing file:  0108_1_06122019_1526
# Processing file:  0402_1_14112019_1110
# Processing file:  0408_1_13122019_1521
# Cz : 0408_1_13122019_1521  removed for deviant tones N1P3 analysis as all its epochs exceed the clip value of 75
# Cz : 0408_1_13122019_1521  removed for incongruent words N4 analysis as all its epochs exceed the clip value of 75
# No Dementia | 12-months | Run 2
# Processing file:  0011_2_22022019_1405
# Processing file:  0037_2_08052019_1116
# Processing file:  0038_2_05122019_1502
# Processing file:  0049_2_15112019_1209
# Processing file:  0066_2_06122019_1441
# Processing file:  0073_2_06122019_1205
# Processing file:  0102_2_12122019_1114
# ...

# %%
print('Mild-Moderate Dementia | Baseline | Run 1')
erpsBMMD_1 = pipeline(filenames=BMMD_1,**args_1)

print('Mild-Moderate Dementia | Baseline | Run 2')
erpsBMMD_2 = pipeline(filenames=BMMD_2,**args_1)
# Out:
# Mild-Moderate Dementia | Baseline | Run 1
# Processing file:  0045_1_01052019_1040
# Processing file:  0085_1_25022019_1113
# Processing file:  0091_1_24042019_1121
# Processing file:  0093_1_08042019_1205
# Processing file:  0111_1_19032019_1032
# Processing file:  0405_1_12042019_1129
# Processing file:  0003_1_15042019_1133
# Processing file:  0007_1_06052019_1001
# Processing file:  0024_1_06032019_1406
# Processing file:  0028_1_17042019_1103
# Processing file:  0048_1_01052019_1110
# Processing file:  0087_1_13032019_1021
# Processing file:  0104_1_08042019_1132
# Processing file:  0115_1_04032019_1445
# Processing file:  0120_1_24042019_1005
# Processing file:  0127_1_10042019_1033
# Mild-Moderate Dementia | Baseline | Run 2
# Processing file:  0045_2_01052019_1047
# Processing file:  0085_2_25022019_1122
# Processing file:  0091_2_24042019_1127
# Processing file:  0093_2_08042019_1212
# Processing file:  0111_2_19032019_1039
# Processing file:  0405_2_12042019_1135
# ...

# %%
print('Mild-Moderate Dementia | 6-months | Run 1')
erps6MMD_1 = pipeline(filenames=MMD6_1,**args_1)

print('Mild-Moderate Dementia | 6-months | Run 2')
erps6MMD_2 = pipeline(filenames=MMD6_2,**args_1)
# Out:
# Mild-Moderate Dementia | 6-months | Run 1
# Processing file:  0045_1_09092019_1121
# Processing file:  0085_1_16072019_1113
# Processing file:  0091_1_28082019_1153
# Processing file:  0111_3_07082019_1117
# Processing file:  0405_1_28082019_1126
# Processing file:  0007_1_04092019_1357
# Processing file:  0024_1_24072019_1139
# Pz : 0024_1_24072019_1139  removed for standard tones N1P3 analysis as all its epochs exceed the clip value of 75
# Pz : 0024_1_24072019_1139  removed for deviant tones N1P3 analysis as all its epochs exceed the clip value of 75
# Pz : 0024_1_24072019_1139  removed for congruent words N4 analysis as all its epochs exceed the clip value of 75
# Pz : 0024_1_24072019_1139  removed for incongruent words N4 analysis as all its epochs exceed the clip value of 75
# Processing file:  0048_1_04092019_1159
# Processing file:  0087_1_30072019_1141
# Processing file:  0104_1_13082019_1447
# Processing file:  0115_1_23072019_1108
# Processing file:  0120_1_20082019_1519
# ...

# %%
print('Mild-Moderate Dementia | 12-months | Run 1')
erps12MMD_1 = pipeline(filenames=MMD12_1,**args_1)

print('Mild-Moderate Dementia | 12-months | Run 2')
erps12MMD_2 = pipeline(filenames=MMD12_2,**args_1)
# Out:
# Mild-Moderate Dementia | 12-months | Run 1
# Processing file:  0045_1_18122019_1111
# Processing file:  0085_1_15112019_1045
# Processing file:  0091_1_12122019_1130
# Processing file:  0405_1_13122019_1425
# Processing file:  0003_1_13122019_1352
# Fz : 0003_1_13122019_1352  removed for standard tones N1P3 analysis as all its epochs exceed the clip value of 75
# Fz : 0003_1_13122019_1352  removed for deviant tones N1P3 analysis as all its epochs exceed the clip value of 75
# Fz : 0003_1_13122019_1352  removed for congruent words N4 analysis as all its epochs exceed the clip value of 75
# Fz : 0003_1_13122019_1352  removed for incongruent words N4 analysis as all its epochs exceed the clip value of 75
# Processing file:  0007_1_06122019_1411
# Processing file:  0028_1_12122019_1046
# Processing file:  0048_1_12122019_1154
# Processing file:  0087_1_06122019_1222
# Pz : 0087_1_06122019_1222  removed for standard tones N1P3 analysis as all its epochs exceed the clip value of 75
# ...

# %%
print('Severe Dementia | Baseline | Run 1')
erpsBSD_1 = pipeline(filenames=BSD_1,**args_1)

print('Severe Dementia | Baseline | Run 2')
erpsBSD_2 = pipeline(filenames=BSD_2,**args_1)
# Out:
# Severe Dementia | Baseline | Run 1
# Processing file:  0002_1_26042019_1008
# Processing file:  0006_1_08042019_1105
# Processing file:  0008_1_04032019_1111
# Processing file:  0031_1_10042019_1145
# Processing file:  0054_1_06052019_1055
# Processing file:  0064_1_15042019_1204
# Processing file:  0069_1_25022019_1353
# Pz : 0069_1_25022019_1353  removed for standard tones N1P3 analysis as all its epochs exceed the clip value of 75
# Pz : 0069_1_25022019_1353  removed for deviant tones N1P3 analysis as all its epochs exceed the clip value of 75
# Pz : 0069_1_25022019_1353  removed for congruent words N4 analysis as all its epochs exceed the clip value of 75
# Pz : 0069_1_25022019_1353  removed for incongruent words N4 analysis as all its epochs exceed the clip value of 75
# Processing file:  0110_1_04032019_1403
# Processing file:  0113_1_21032019_1117
# Processing file:  0123_1_19032019_1104
# Processing file:  0134_1_21032019_1213
# Processing file:  0406_1_15042019_1047
# ...

# %%
print('Severe Dementia | 6-months | Run 1')
erps6SD_1 = pipeline(filenames=SD6_1,**args_1)
 
print('Severe Dementia | 6-months | Run 2')
erps6SD_2 = pipeline(filenames=SD6_2,**args_1)
# Out:
# Severe Dementia | 6-months | Run 1
# Processing file:  0002_1_03092019_1137
# Processing file:  0006_1_13082019_1134
# Processing file:  0026_1_31072019_1201
# Processing file:  0031_1_13082019_1506
# Processing file:  0054_1_04092019_1439
# Processing file:  0069_1_15072019_1112
# Processing file:  0110_1_23072019_1153
# Processing file:  0113_1_07082019_1129
# Processing file:  0134_1_07082019_1350
# Processing file:  0135_1_09092019_1148
# Processing file:  0406_1_20082019_1100
# Fz : 0406_1_20082019_1100  removed for deviant tones N1P3 analysis as all its epochs exceed the clip value of 75
# Fz : 0406_1_20082019_1100  removed for congruent words N4 analysis as all its epochs exceed the clip value of 75
# Processing file:  0407_1_03092019_1117
# Severe Dementia | 6-months | Run 2
# Processing file:  0002_2_03092019_1143
# Processing file:  0006_2_13082019_1140
# Processing file:  0026_2_31072019_1208
# Processing file:  0031_2_13082019_1512
# ...

# %%
print('Severe Dementia | 12-months | Run 1')
erps12SD_1 = pipeline(filenames=SD12_1,**args_1)

print('Severe Dementia | 12-months | Run 2')
erps12SD_2 = pipeline(filenames=SD12_2,**args_1)
# Out:
# Severe Dementia | 12-months | Run 1
# Processing file:  0002_1_12122019_1219
# Processing file:  0006_1_05122019_1404
# Processing file:  0008_1_15112019_1115
# Processing file:  0031_1_05122019_1428
# Processing file:  0069_1_15112019_1144
# Processing file:  0110_1_21112019_1051
# Cz : 0110_1_21112019_1051  removed for standard tones N1P3 analysis as all its epochs exceed the clip value of 75
# Cz : 0110_1_21112019_1051  removed for deviant tones N1P3 analysis as all its epochs exceed the clip value of 75
# Cz : 0110_1_21112019_1051  removed for congruent words N4 analysis as all its epochs exceed the clip value of 75
# Cz : 0110_1_21112019_1051  removed for incongruent words N4 analysis as all its epochs exceed the clip value of 75
# Processing file:  0113_1_06122019_1348
# Processing file:  0134_1_06122019_1458
# Processing file:  0135_1_18122019_1138
# Fz : 0135_1_18122019_1138  removed for deviant tones N1P3 analysis as all its epochs exceed the clip value of 75
# ...

# %% [markdown]
# <b>Compute PSDs<b>

# %%
args_2 = {'deviceVersion':1.0,'path':'/Users/joshuaighalo/Downloads/brainNet_datasets/laurel_place/cleaned_dataset',
        'sfreq':cfg.fs,'line':cfg.line,'highPass':0.5,'lowPass':45,'stimTriggers':cfg.stimTrig,'clip':cfg.clip,
        'channel_names':['Fz','Cz','Pz'],'Epochs_MultipleSubjects':True}

# %%
psdBND_1,psdBND_2 = generatePSDsUsingEpochs(BND_1,BND_2,**args_2)
psd6ND_1,psd6ND_2 = generatePSDsUsingEpochs(ND6_1,ND6_2,**args_2)
psd12ND_1,psd12ND_2 = generatePSDsUsingEpochs(ND12_1,ND12_2,**args_2)
psdBMMD_1,psdBMMD_2 = generatePSDsUsingEpochs(BMMD_1,BMMD_2,**args_2)
psd6MMD_1,psd6MMD_2 = generatePSDsUsingEpochs(MMD6_1,MMD6_2,**args_2)
psd12MMD_1,psd12MMD_2 = generatePSDsUsingEpochs(MMD12_1,MMD12_2,**args_2)
psdBSD_1,psdBSD_2 = generatePSDsUsingEpochs(BSD_1,BSD_2,**args_2)
psd6SD_1,psd6SD_2 = generatePSDsUsingEpochs(SD6_1,SD6_2,**args_2)
psd12SD_1,psd12SD_2 = generatePSDsUsingEpochs(SD12_1,SD12_2,**args_2)
freqs = psdBND_1[4][0]
# Out:
# Processing file:  0038_1_21032019_1045
# Processing file:  0049_1_25022019_1154
# Processing file:  0066_1_26042019_0944
# Processing file:  0073_1_13032019_1057
# Processing file:  0074_1_09062017_1048
# Processing file:  0075_1_22022019_1136
# Processing file:  0102_1_24042019_1042
# Processing file:  0108_1_21032019_1014
# Processing file:  0114_1_17042019_1143
# Processing file:  0408_1_01052019_1006
# Processing file:  0038_2_21032019_1051
# Processing file:  0049_2_25022019_1202
# Processing file:  0066_2_26042019_0951
# Processing file:  0073_2_13032019_1104
# Processing file:  0074_2_09062017_1055
# Processing file:  0075_2_22022019_1147
# Processing file:  0102_2_24042019_1049
# Processing file:  0108_2_21032019_1022
# Processing file:  0114_2_17042019_1150
# Processing file:  0408_2_01052019_1013
# Processing file:  0005_1_03092019_1155
# Processing file:  0038_1_07082019_1432
# Processing file:  0049_1_16072019_1044
# Processing file:  0066_1_27082019_1141
# ...

# %% [markdown]
# <b>Correlation Analysis<b>

# %%
search_path = r'/Users/joshuaighalo/Downloads/brainNet_datasets/laurel_place/cleaned_dataset/'
df_1 = pd.read_excel (search_path +'lp_clinical.xlsx')
df_2 = pd.read_excel(search_path + 'Scan_details.xlsx')
clinical_data = (df_1[['ID','MMSE']]).to_numpy()

def string2integer(filename):
    return int(filename[:-16])

#   convert the string filenames used for psd computation to integers
filenamesBND_1,filenamesBND_2 = np.array([string2integer(filename) for filename in BND_1]),np.array([string2integer(filename) for filename in BND_2])
filenames6ND_1,filenames6ND_2 = np.array([string2integer(filename) for filename in ND6_1]),np.array([string2integer(filename) for filename in ND6_2])
filenames12ND_1,filenames12ND_2 = np.array([string2integer(filename) for filename in ND12_1]),np.array([string2integer(filename) for filename in ND12_2])
filenamesBMMD_1,filenamesBMMD_2 = np.array([string2integer(filename) for filename in BMMD_1]),np.array([string2integer(filename) for filename in BMMD_2])
filenames6MMD_1,filenames6MMD_2 = np.array([string2integer(filename) for filename in MMD6_1]),np.array([string2integer(filename) for filename in MMD6_2])
filenames12MMD_1,filenames12MMD_2 = np.array([string2integer(filename) for filename in MMD12_1]),np.array([string2integer(filename) for filename in MMD12_2])
filenamesBSD_1,filenamesBSD_2 = np.array([string2integer(filename) for filename in BSD_1]), np.array([string2integer(filename) for filename in BSD_2])
filenames6SD_1,filenames6SD_2 = np.array([string2integer(filename) for filename in SD6_1]),np.array([string2integer(filename) for filename in SD6_2])
filenames12SD_1,filenames12SD_2 = np.array([string2integer(filename) for filename in SD12_1]),np.array([string2integer(filename) for filename in SD12_2])

# %%
# use filenames to get MMSE scores
MMSE_BND = np.array([clinical_data[clinical_data[:,0]==filename][0][1] for filename in filenamesBND_1])
MMSE_6ND = np.array([clinical_data[clinical_data[:,0]==filename][0][1] for filename in filenames6ND_1])
MMSE_12ND = np.array([clinical_data[clinical_data[:,0]==filename][0][1] for filename in filenames12ND_1])

MMSE_BMMD = np.array([clinical_data[clinical_data[:,0]==filename][0][1] for filename in filenamesBMMD_1])
MMSE_6MMD = np.array([clinical_data[clinical_data[:,0]==filename][0][1] for filename in filenames6MMD_1])
MMSE_12MMD = np.array([clinical_data[clinical_data[:,0]==filename][0][1] for filename in filenames12MMD_1])

MMSE_BSD = np.array([clinical_data[clinical_data[:,0]==filename][0][1] for filename in filenamesBSD_1])
MMSE_6SD = np.array([clinical_data[clinical_data[:,0]==filename][0][1] for filename in filenames6SD_1])
MMSE_12SD = np.array([clinical_data[clinical_data[:,0]==filename][0][1] for filename in filenames12SD_1])

# %%
def peakPower(psd_1,psd_2,freqs,frqrange):
    #   Utilizes MultiTaper method to calculate the average power of a band
    #  Inputs  :   data    - 2D numpy array (d0 = samples, d1 = channels) of filtered EEG data
    #              low     - lower limit in Hz for the brain wave
    #              high    - upper limit in Hz for the brain wave
    #   Output  :   3D array (columns of array,no of windows,window size)
    def param_1(data_1,frequency,freqrange):
        idxFreq_1 = np.abs(frequency - freqrange[0]).argmin()
        idxFreq_2 = np.abs(frequency - freqrange[1]).argmin()
        psdRange = data_1[idxFreq_1:idxFreq_2]
        peakPower = np.max(psdRange)
        return peakPower  
    def param_2(data_2,frequency,freqrange):
        idxFreq_1 = np.abs(frequency - freqrange[0]).argmin()
        idxFreq_2 = np.abs(frequency - freqrange[1]).argmin()
        psdRange = data_2[idxFreq_1:idxFreq_2]
        peakPower = np.max(psdRange)
        return peakPower

    peakPower_1,peakPower_2 = [],[]
    for i in range(len(psd_1)):
        peakPower_1.append(param_1(psd_1[i],freqs,frqrange))
    peakPower_1 = np.array(peakPower_1)
    for i in range(len(psd_2)):
        peakPower_2.append(param_2(psd_2[i],freqs,frqrange))
    peakPower_2 = np.array(peakPower_2)
    return peakPower_1,peakPower_2

# %%
#  Baseline No Dementia
fz_psdBND_1,fz_psdBND_2 = peakPower(psdBND_1[0],psdBND_2[0],freqs,[8,12])
cz_psdBND_1,cz_psdBND_2 = peakPower(psdBND_1[1],psdBND_2[1],freqs,[8,12])
pz_psdBND_1,pz_psdBND_2 = peakPower(psdBND_1[2],psdBND_2[2],freqs,[8,12])
glo_psdBND_1,glo_psdBND_2 = peakPower(psdBND_1[3],psdBND_2[3],freqs,[8,12])
#  6 Months No Dementia
fz_psd6ND_1,fz_psd6ND_2 = peakPower(psd6ND_1[0],psd6ND_2[0],freqs,[8,12])
cz_psd6ND_1,cz_psd6ND_2 = peakPower(psd6ND_1[1],psd6ND_2[1],freqs,[8,12])
pz_psd6ND_1,pz_psd6ND_2 = peakPower(psd6ND_1[2],psd6ND_2[2],freqs,[8,12])
glo_psd6ND_1,glo_psd6ND_2 = peakPower(psd6ND_1[3],psd6ND_2[3],freqs,[8,12])
#  12 Months No Dementia
fz_psd12ND_1,fz_psd12ND_2 = peakPower(psd12ND_1[0],psd12ND_2[0],freqs,[8,12])
cz_psd12ND_1,cz_psd12ND_2 = peakPower(psd12ND_1[1],psd12ND_2[1],freqs,[8,12])
pz_psd12ND_1,pz_psd12ND_2 = peakPower(psd12ND_1[2],psd12ND_2[2],freqs,[8,12])
glo_psd12ND_1,glo_psd12ND_2 = peakPower(psd12ND_1[3],psd12ND_2[3],freqs,[8,12])

#  Baseline Mild-Moderate Dementia
fz_psdBMMD_1,fz_psdBMMD_2 = peakPower(psdBMMD_1[0],psdBMMD_2[0],freqs,[8,12])
cz_psdBMMD_1,cz_psdBMMD_2 = peakPower(psdBMMD_1[1],psdBMMD_2[1],freqs,[8,12])
pz_psdBMMD_1,pz_psdBMMD_2 = peakPower(psdBMMD_1[2],psdBMMD_2[2],freqs,[8,12])
glo_psdBMMD_1,glo_psdBMMD_2 = peakPower(psdBMMD_1[3],psdBMMD_2[3],freqs,[8,12])
#  6 Months Mild-Moderate Dementia
fz_psd6MMD_1,fz_psd6MMD_2 = peakPower(psd6MMD_1[0],psd6MMD_2[0],freqs,[8,12])
cz_psd6MMD_1,cz_psd6MMD_2 = peakPower(psd6MMD_1[1],psd6MMD_2[1],freqs,[8,12])
pz_psd6MMD_1,pz_psd6MMD_2 = peakPower(psd6MMD_1[2],psd6MMD_2[2],freqs,[8,12])
glo_psd6MMD_1,glo_psd6MMD_2 = peakPower(psd6MMD_1[3],psd6MMD_2[3],freqs,[8,12])
#  12 Months Mild-Moderate Dementia
fz_psd12MMD_1,fz_psd12MMD_2 = peakPower(psd12MMD_1[0],psd12MMD_2[0],freqs,[8,12])
cz_psd12MMD_1,cz_psd12MMD_2 = peakPower(psd12MMD_1[1],psd12MMD_2[1],freqs,[8,12])
pz_psd12MMD_1,pz_psd12MMD_2 = peakPower(psd12MMD_1[2],psd12MMD_2[2],freqs,[8,12])
glo_psd12MMD_1,glo_psd12MMD_2 = peakPower(psd12MMD_1[3],psd12MMD_2[3],freqs,[8,12])

#  Baseline Severe Dementia
fz_psdBSD_1,fz_psdBSD_2 = peakPower(psdBSD_1[0],psdBSD_2[0],freqs,[8,12])
cz_psdBSD_1,cz_psdBSD_2 = peakPower(psdBSD_1[1],psdBSD_2[1],freqs,[8,12])
pz_psdBSD_1,pz_psdBSD_2 = peakPower(psdBSD_1[2],psdBSD_2[2],freqs,[8,12])
glo_psdBSD_1,glo_psdBSD_2 = peakPower(psdBSD_1[3],psdBSD_2[3],freqs,[8,12])
#  6 Months Severe Dementia
fz_psd6SD_1,fz_psd6SD_2 = peakPower(psd6SD_1[0],psd6SD_2[0],freqs,[8,12])
cz_psd6SD_1,cz_psd6SD_2 = peakPower(psd6SD_1[1],psd6SD_2[1],freqs,[8,12])
pz_psd6SD_1,pz_psd6SD_2 = peakPower(psd6SD_1[2],psd6SD_2[2],freqs,[8,12])
glo_psd6SD_1,glo_psd6SD_2 = peakPower(psd6SD_1[3],psd6SD_2[3],freqs,[8,12])
#  12 Months Severe Dementia
fz_psd12SD_1,fz_psd12SD_2 = peakPower(psd12SD_1[0],psd12SD_2[0],freqs,[8,12])
cz_psd12SD_1,cz_psd12SD_2 = peakPower(psd12SD_1[1],psd12SD_2[1],freqs,[8,12])
pz_psd12SD_1,pz_psd12SD_2 = peakPower(psd12SD_1[2],psd12SD_2[2],freqs,[8,12])
glo_psd12SD_1,glo_psd12SD_2 = peakPower(psd12SD_1[3],psd12SD_2[3],freqs,[8,12])

# %%
#  Difference between run 1 and run 2
fz_psdBND_diff,cz_psdBND_diff,pz_psdBND_diff,glo_psdBND_diff = fz_psdBND_2 - fz_psdBND_1,cz_psdBND_2 - cz_psdBND_1,pz_psdBND_2 - pz_psdBND_1,glo_psdBND_2 - glo_psdBND_1
fz_psd6ND_diff,cz_psd6ND_diff,pz_psd6ND_diff,glo_psd6ND_diff = fz_psd6ND_2 - fz_psd6ND_1,cz_psd6ND_2 - cz_psd6ND_1,pz_psd6ND_2 - pz_psd6ND_1,glo_psd6ND_2 - glo_psd6ND_1
fz_psd12ND_diff,cz_psd12ND_diff,pz_psd12ND_diff,glo_psd12ND_diff = fz_psd12ND_2 - fz_psd12ND_1,cz_psd12ND_2 - cz_psd12ND_1,pz_psd12ND_2 - pz_psd12ND_1,glo_psd12ND_2 - glo_psd12ND_1
fz_psdBMMD_diff,cz_psdBMMD_diff,pz_psdBMMD_diff,glo_psdBMMD_diff = fz_psdBMMD_2 - fz_psdBMMD_1,cz_psdBMMD_2 - cz_psdBMMD_1,pz_psdBMMD_2 - pz_psdBMMD_1,glo_psdBMMD_2 - glo_psdBMMD_1
fz_psd6MMD_diff,cz_psd6MMD_diff,pz_psd6MMD_diff,glo_psd6MMD_diff = fz_psd6MMD_2 - fz_psd6MMD_1,cz_psd6MMD_2 - cz_psd6MMD_1,pz_psd6MMD_2 - pz_psd6MMD_1,glo_psd6MMD_2 - glo_psd6MMD_1
fz_psd12MMD_diff,cz_psd12MMD_diff,pz_psd12MMD_diff,glo_psd12MMD_diff = fz_psd12MMD_2 - fz_psd12MMD_1,cz_psd12MMD_2 - cz_psd12MMD_1,pz_psd12MMD_2 - pz_psd12MMD_1,glo_psd12MMD_2 - glo_psd12MMD_1
fz_psdBSD_diff,cz_psdBSD_diff,pz_psdBSD_diff,glo_psdBSD_diff = fz_psdBSD_2 - fz_psdBSD_1,cz_psdBSD_2 - cz_psdBSD_1,pz_psdBSD_2 - pz_psdBSD_1,glo_psdBSD_2 - glo_psdBSD_1
fz_psd6SD_diff,cz_psd6SD_diff,pz_psd6SD_diff,glo_psd6SD_diff = fz_psd6SD_2 - fz_psd6SD_1,cz_psd6SD_2 - cz_psd6SD_1,pz_psd6SD_2 - pz_psd6SD_1,glo_psd6SD_2 - glo_psd6SD_1
fz_psd12SD_diff,cz_psd12SD_diff,pz_psd12SD_diff,glo_psd12SD_diff = fz_psd12SD_2 - fz_psd12SD_1,cz_psd12SD_2 - cz_psd12SD_1,pz_psd12SD_2 - pz_psd12SD_1,glo_psd12SD_2 - glo_psd12SD_1

# %%
#   Replace NaNs with mean
fz_psdBND_diff[np.isnan(fz_psdBND_diff)], cz_psdBND_diff[np.isnan(cz_psdBND_diff)] = np.nanmean(fz_psdBND_diff),np.nanmean(cz_psdBND_diff)
pz_psdBND_diff[np.isnan(pz_psdBND_diff)], glo_psdBND_diff[np.isnan(glo_psdBND_diff)] = np.nanmean(pz_psdBND_diff),np.nanmean(glo_psdBND_diff)
fz_psd6ND_diff[np.isnan(fz_psd6ND_diff)], cz_psd6ND_diff[np.isnan(cz_psd6ND_diff)] = np.nanmean(fz_psd6ND_diff),np.nanmean(cz_psd6ND_diff)
pz_psd6ND_diff[np.isnan(pz_psd6ND_diff)], glo_psd6ND_diff[np.isnan(glo_psd6ND_diff)] = np.nanmean(pz_psd6ND_diff),np.nanmean(glo_psd6ND_diff)
fz_psd12ND_diff[np.isnan(fz_psd12ND_diff)], cz_psd12ND_diff[np.isnan(cz_psd12ND_diff)] = np.nanmean(fz_psd12ND_diff),np.nanmean(cz_psd12ND_diff)
pz_psd12ND_diff[np.isnan(pz_psd12ND_diff)], glo_psd12ND_diff[np.isnan(glo_psd12ND_diff)] = np.nanmean(pz_psd12ND_diff),np.nanmean(glo_psd12ND_diff)

fz_psdBMMD_diff[np.isnan(fz_psdBMMD_diff)], cz_psdBMMD_diff[np.isnan(cz_psdBMMD_diff)] = np.nanmean(fz_psdBMMD_diff),np.nanmean(cz_psdBMMD_diff)
pz_psdBMMD_diff[np.isnan(pz_psdBMMD_diff)], glo_psdBMMD_diff[np.isnan(glo_psdBMMD_diff)] = np.nanmean(pz_psdBMMD_diff),np.nanmean(glo_psdBMMD_diff)
fz_psd6MMD_diff[np.isnan(fz_psd6MMD_diff)], cz_psd6MMD_diff[np.isnan(cz_psd6MMD_diff)] = np.nanmean(fz_psd6MMD_diff),np.nanmean(cz_psd6MMD_diff)
pz_psd6MMD_diff[np.isnan(pz_psd6MMD_diff)], glo_psd6MMD_diff[np.isnan(glo_psd6MMD_diff)] = np.nanmean(pz_psd6MMD_diff),np.nanmean(glo_psd6MMD_diff)
fz_psd12MMD_diff[np.isnan(fz_psd12MMD_diff)], cz_psd12MMD_diff[np.isnan(cz_psd12MMD_diff)] = np.nanmean(fz_psd12MMD_diff),np.nanmean(cz_psd12MMD_diff)
pz_psd12MMD_diff[np.isnan(pz_psd12MMD_diff)], glo_psd12MMD_diff[np.isnan(glo_psd12MMD_diff)] = np.nanmean(pz_psd12MMD_diff),np.nanmean(glo_psd12MMD_diff)

fz_psdBSD_diff[np.isnan(fz_psdBSD_diff)], cz_psdBSD_diff[np.isnan(cz_psdBSD_diff)] = np.nanmean(fz_psdBSD_diff),np.nanmean(cz_psdBSD_diff)
pz_psdBSD_diff[np.isnan(pz_psdBSD_diff)], glo_psdBSD_diff[np.isnan(glo_psdBSD_diff)] = np.nanmean(pz_psdBSD_diff),np.nanmean(glo_psdBSD_diff)
fz_psd6SD_diff[np.isnan(fz_psd6SD_diff)], cz_psd6SD_diff[np.isnan(cz_psd6SD_diff)] = np.nanmean(fz_psd6SD_diff),np.nanmean(cz_psd6SD_diff)
pz_psd6SD_diff[np.isnan(pz_psd6SD_diff)], glo_psd6SD_diff[np.isnan(glo_psd6SD_diff)] = np.nanmean(pz_psd6SD_diff),np.nanmean(glo_psd6SD_diff)
fz_psd12SD_diff[np.isnan(fz_psd12SD_diff)], cz_psd12SD_diff[np.isnan(cz_psd12SD_diff)] = np.nanmean(fz_psd12SD_diff),np.nanmean(cz_psd12SD_diff)
pz_psd12SD_diff[np.isnan(pz_psd12SD_diff)], glo_psd12SD_diff[np.isnan(glo_psd12SD_diff)] = np.nanmean(pz_psd12SD_diff),np.nanmean(glo_psd12SD_diff)

# %%
#  Correlations between PSD difference and MMSE
fz_psdBND_corr,cz_psdBND_corr = np.corrcoef(fz_psdBND_diff,MMSE_BND)[0,1],np.corrcoef(cz_psdBND_diff,MMSE_BND)[0,1]
pz_psdBND_corr,glo_psdBND_corr = np.corrcoef(pz_psdBND_diff,MMSE_BND)[0,1],np.corrcoef(glo_psdBND_diff,MMSE_BND)[0,1]
fz_psd6ND_corr,cz_psd6ND_corr = np.corrcoef(fz_psd6ND_diff,MMSE_6ND)[0,1],np.corrcoef(cz_psd6ND_diff,MMSE_6ND)[0,1]
pz_psd6ND_corr,glo_psd6ND_corr = np.corrcoef(pz_psd6ND_diff,MMSE_6ND)[0,1],np.corrcoef(glo_psd6ND_diff,MMSE_6ND)[0,1]
fz_psd12ND_corr,cz_psd12ND_corr = np.corrcoef(fz_psd12ND_diff,MMSE_12ND)[0,1],np.corrcoef(cz_psd12ND_diff,MMSE_12ND)[0,1]
pz_psd12ND_corr,glo_psd12ND_corr = np.corrcoef(pz_psd12ND_diff,MMSE_12ND)[0,1],np.corrcoef(glo_psd12ND_diff,MMSE_12ND)[0,1]

fz_psdBMMD_corr,cz_psdBMMD_corr = np.corrcoef(fz_psdBMMD_diff,MMSE_BMMD)[0,1],np.corrcoef(cz_psdBMMD_diff,MMSE_BMMD)[0,1]
pz_psdBMMD_corr,glo_psdBMMD_corr = np.corrcoef(pz_psdBMMD_diff,MMSE_BMMD)[0,1],np.corrcoef(glo_psdBMMD_diff,MMSE_BMMD)[0,1]
fz_psd6MMD_corr,cz_psd6MMD_corr = np.corrcoef(fz_psd6MMD_diff,MMSE_6MMD)[0,1],np.corrcoef(cz_psd6MMD_diff,MMSE_6MMD)[0,1]
pz_psd6MMD_corr,glo_psd6MMD_corr = np.corrcoef(pz_psd6MMD_diff,MMSE_6MMD)[0,1],np.corrcoef(glo_psd6MMD_diff,MMSE_6MMD)[0,1]
fz_psd12MMD_corr,cz_psd12MMD_corr = np.corrcoef(fz_psd12MMD_diff,MMSE_12MMD)[0,1],np.corrcoef(cz_psd12MMD_diff,MMSE_12MMD)[0,1]
pz_psd12MMD_corr,glo_psd12MMD_corr = np.corrcoef(pz_psd12MMD_diff,MMSE_12MMD)[0,1],np.corrcoef(glo_psd12MMD_diff,MMSE_12MMD)[0,1]

fz_psdBSD_corr,cz_psdBSD_corr = np.corrcoef(fz_psdBSD_diff,MMSE_BSD)[0,1],np.corrcoef(cz_psdBSD_diff,MMSE_BSD)[0,1]
pz_psdBSD_corr,glo_psdBSD_corr = np.corrcoef(pz_psdBSD_diff,MMSE_BSD)[0,1],np.corrcoef(glo_psdBSD_diff,MMSE_BSD)[0,1]
fz_psd6SD_corr,cz_psd6SD_corr = np.corrcoef(fz_psd6SD_diff,MMSE_6SD)[0,1],np.corrcoef(cz_psd6SD_diff,MMSE_6SD)[0,1]
pz_psd6SD_corr,glo_psd6SD_corr = np.corrcoef(pz_psd6SD_diff,MMSE_6SD)[0,1],np.corrcoef(glo_psd6SD_diff,MMSE_6SD)[0,1]
fz_psd12SD_corr,cz_psd12SD_corr = np.corrcoef(fz_psd12SD_diff,MMSE_12SD)[0,1],np.corrcoef(cz_psd12SD_diff,MMSE_12SD)[0,1]
pz_psd12SD_corr,glo_psd12SD_corr = np.corrcoef(pz_psd12SD_diff,MMSE_12SD)[0,1],np.corrcoef(glo_psd12SD_diff,MMSE_12SD)[0,1]

# %%
# Plotting
fig,ax = plt.subplots(3,3,figsize=(15,10))
fig.tight_layout(pad=3.0)
ax[0,0].scatter(fz_psdBND_diff,MMSE_BND)
ax[0,0].set_title('Fz, BND, corr = '+str(round(fz_psdBND_corr,2)))
ax[0,1].scatter(cz_psdBND_diff,MMSE_BND)
ax[0,1].set_title('Cz, BND, corr = '+str(round(cz_psdBND_corr,2)))
ax[0,2].scatter(pz_psdBND_diff,MMSE_BND)
ax[0,2].set_title('Pz, BND, corr = '+str(round(pz_psdBND_corr,2)))
ax[1,0].scatter(fz_psd6ND_diff,MMSE_6ND)
ax[1,0].set_title('Fz, 6ND, corr = '+str(round(fz_psd6ND_corr,2)))
ax[1,1].scatter(cz_psd6ND_diff,MMSE_6ND)
ax[1,1].set_title('Cz, 6ND, corr = '+str(round(cz_psd6ND_corr,2)))
ax[1,2].scatter(pz_psd6ND_diff,MMSE_6ND)
ax[1,2].set_title('Pz, 6ND, corr = '+str(round(pz_psd6ND_corr,2)))
ax[2,0].scatter(fz_psd12ND_diff,MMSE_12ND)
ax[2,0].set_title('Fz, 12ND, corr = '+str(round(fz_psd12ND_corr,2)))
ax[2,1].scatter(cz_psd12ND_diff,MMSE_12ND)
ax[2,1].set_title('Cz, 12ND, corr = '+str(round(cz_psd12ND_corr,2)))
ax[2,2].scatter(pz_psd12ND_diff,MMSE_12ND)
ax[2,2].set_title('Pz, 12ND, corr = '+str(round(pz_psd12ND_corr,2)))
plt.show()

fig,ax = plt.subplots(3,3,figsize=(15,10))
fig.tight_layout(pad=3.0)
ax[0,0].scatter(fz_psdBMMD_diff,MMSE_BMMD)
ax[0,0].set_title('Fz, BMMD, corr = '+str(round(fz_psdBMMD_corr,2)))
ax[0,1].scatter(cz_psdBMMD_diff,MMSE_BMMD)
ax[0,1].set_title('Cz, BMMD, corr = '+str(round(cz_psdBMMD_corr,2)))
ax[0,2].scatter(pz_psdBMMD_diff,MMSE_BMMD)
ax[0,2].set_title('Pz, BMMD, corr = '+str(round(pz_psdBMMD_corr,2)))
ax[1,0].scatter(fz_psd6MMD_diff,MMSE_6MMD)
ax[1,0].set_title('Fz, 6MMD, corr = '+str(round(fz_psd6MMD_corr,2)))
ax[1,1].scatter(cz_psd6MMD_diff,MMSE_6MMD)
ax[1,1].set_title('Cz, 6MMD, corr = '+str(round(cz_psd6MMD_corr,2)))
ax[1,2].scatter(pz_psd6MMD_diff,MMSE_6MMD)
ax[1,2].set_title('Pz, 6MMD, corr = '+str(round(pz_psd6MMD_corr,2)))
ax[2,0].scatter(fz_psd12MMD_diff,MMSE_12MMD)
ax[2,0].set_title('Fz, 12MMD, corr = '+str(round(fz_psd12MMD_corr,2)))
ax[2,1].scatter(cz_psd12MMD_diff,MMSE_12MMD)
ax[2,1].set_title('Cz, 12MMD, corr = '+str(round(cz_psd12MMD_corr,2)))
ax[2,2].scatter(pz_psd12MMD_diff,MMSE_12MMD)
ax[2,2].set_title('Pz, 12MMD, corr = '+str(round(pz_psd12MMD_corr,2)))
plt.show()

fig,ax = plt.subplots(3,3,figsize=(15,10))
fig.tight_layout(pad=3.0)
ax[0,0].scatter(fz_psdBSD_diff,MMSE_BSD)
ax[0,0].set_title('Fz, BSD, corr = '+str(round(fz_psdBSD_corr,2)))
ax[0,1].scatter(cz_psdBSD_diff,MMSE_BSD)
ax[0,1].set_title('Cz, BSD, corr = '+str(round(cz_psdBSD_corr,2)))
ax[0,2].scatter(pz_psdBSD_diff,MMSE_BSD)
ax[0,2].set_title('Pz, BSD, corr = '+str(round(pz_psdBSD_corr,2)))
ax[1,0].scatter(fz_psd6SD_diff,MMSE_6SD)
ax[1,0].set_title('Fz, 6SD, corr = '+str(round(fz_psd6SD_corr,2)))
ax[1,1].scatter(cz_psd6SD_diff,MMSE_6SD)
ax[1,1].set_title('Cz, 6SD, corr = '+str(round(cz_psd6SD_corr,2)))
ax[1,2].scatter(pz_psd6SD_diff,MMSE_6SD)
ax[1,2].set_title('Pz, 6SD, corr = '+str(round(pz_psd6SD_corr,2)))
ax[2,0].scatter(fz_psd12SD_diff,MMSE_12SD)
ax[2,0].set_title('Fz, 12SD, corr = '+str(round(fz_psd12SD_corr,2)))
ax[2,1].scatter(cz_psd12SD_diff,MMSE_12SD)
ax[2,1].set_title('Cz, 12SD, corr = '+str(round(cz_psd12SD_corr,2)))
ax[2,2].scatter(pz_psd12SD_diff,MMSE_12SD)
ax[2,2].set_title('Pz, 12SD, corr = '+str(round(pz_psd12SD_corr,2)))
plt.show()

# %% [markdown]
# <B>Export Datasets<B>

# %%
npydir = "/Users/joshuaighalo/Documents/BrainNet/Projects/Workspace/Datasets/cognitiveFatigue/new/"
np.save(npydir + 'psdBND_1',psdBND_1),np.save(npydir + 'psdBND_2',psdBND_2)
np.save(npydir + 'psd6ND_1',psd6ND_1),np.save(npydir + 'psd6ND_2',psd6ND_2)
np.save(npydir + 'psd12ND_1',psd12ND_1),np.save(npydir + 'psd12ND_2',psd12ND_2)
np.save(npydir + 'psdBMMD_1',psdBMMD_1),np.save(npydir + 'psdBMMD_2',psdBMMD_2)
np.save(npydir + 'psd6MMD_1',psd6MMD_1),np.save(npydir + 'psd6MMD_2',psd6MMD_2)
np.save(npydir + 'psd12MMD_1',psd12MMD_1),np.save(npydir + 'psd12MMD_2',psd12MMD_2)
np.save(npydir + 'psdBSD_1',psdBSD_1),np.save(npydir + 'psdBSD_2',psdBSD_2)
np.save(npydir + 'psd6SD_1',psd6SD_1),np.save(npydir + 'psd6SD_2',psd6SD_2)
np.save(npydir + 'psd12SD_1',psd12SD_1),np.save(npydir + 'psd12SD_2',psd12SD_2)

# %% [markdown]
# <b>Visualization<b>

# %%
psdBND_1,psdBND_2 = np.nanmean(psdBND_1,axis=1),np.nanmean(psdBND_2,axis=1)
psd6ND_1,psd6ND_2 = np.nanmean(psd6ND_1,axis=1),np.nanmean(psd6ND_2,axis=1)
psd12ND_1,psd12ND_2 = np.nanmean(psd12ND_1,axis=1),np.nanmean(psd12ND_2,axis=1)
psdBMMD_1,psdBMMD_2 = np.nanmean(psdBMMD_1,axis=1),np.nanmean(psdBMMD_2,axis=1)
psd6MMD_1,psd6MMD_2 = np.nanmean(psd6MMD_1,axis=1),np.nanmean(psd6MMD_2,axis=1)
psd12MMD_1,psd12MMD_2 = np.nanmean(psd12MMD_1,axis=1),np.nanmean(psd12MMD_2,axis=1)
psdBSD_1,psdBSD_2 = np.nanmean(psdBSD_1,axis=1),np.nanmean(psdBSD_2,axis=1)
psd6SD_1,psd6SD_2 = np.nanmean(psd6SD_1,axis=1),np.nanmean(psd6SD_2,axis=1)
psd12SD_1,psd12SD_2 = np.nanmean(psd12SD_1,axis=1),np.nanmean(psd12SD_2,axis=1)

# %% [markdown]
# No Dementia across TimePoints

# %%
fig,ax = plt.subplots(1,4,figsize=(30,6))
fig.suptitle('No Dementia | Baseline',fontsize=15)
ax[0].set_title('Fz')
ax[0].plot(freqs,psdBND_1[0],label='Run 1',color='red',linewidth=1)
ax[0].plot(freqs,psdBND_2[0],label='Run 2',color='blue',linewidth=1)
ax[1].set_title('Cz')
ax[1].plot(freqs,psdBND_1[1],label='Run 1',color='red',linewidth=1)
ax[1].plot(freqs,psdBND_2[1],label='Run 2',color='blue',linewidth=1)
ax[2].set_title('Pz')
ax[2].plot(freqs,psdBND_1[2],label='Run 1',color='red',linewidth=1)
ax[2].plot(freqs,psdBND_2[2],label='Run 2',color='blue',linewidth=1)
ax[3].set_title('Global')
ax[3].plot(freqs,psdBND_1[3],label='Run 1',color='red',linewidth=1)
ax[3].plot(freqs,psdBND_2[3],label='Run 2',color='blue',linewidth=1)
ax[0].set_ylabel('PSD')
ax[0].set_xlabel('Frequency (Hz)')
ax[1].set_xlabel('Frequency (Hz)')
ax[2].set_xlabel('Frequency (Hz)')
ax[3].set_xlabel('Frequency (Hz)')
ax[0].set_ylim([0,17])
ax[1].set_ylim([0,17])
ax[2].set_ylim([0,17])
ax[3].set_ylim([0,17])
ax[0].set_xlim([0,50])
ax[1].set_xlim([0,50])
ax[2].set_xlim([0,50])
ax[3].set_xlim([0,50])
ax[0].set_xticks(np.arange(0, 50, 5))
ax[1].set_xticks(np.arange(0, 50, 5))
ax[2].set_xticks(np.arange(0, 50, 5))
ax[3].set_xticks(np.arange(0, 50, 5))
ax[0].legend()
ax[1].legend()
ax[2].legend()
ax[3].legend()
 
fig,ax = plt.subplots(1,4,figsize=(30,6))
fig.suptitle('No Dementia | 6-months',fontsize=15)
ax[0].set_title('Fz')
ax[0].plot(freqs,psd6ND_1[0],label='Run 1',color='red',linewidth=1)
ax[0].plot(freqs,psd6ND_2[0],label='Run 2',color='blue',linewidth=1)
ax[1].set_title('Cz')
ax[1].plot(freqs,psd6ND_1[1],label='Run 1',color='red',linewidth=1)
ax[1].plot(freqs,psd6ND_2[1],label='Run 2',color='blue',linewidth=1)
ax[2].set_title('Pz')
ax[2].plot(freqs,psd6ND_1[2],label='Run 1',color='red',linewidth=1)
ax[2].plot(freqs,psd6ND_2[2],label='Run 2',color='blue',linewidth=1)
ax[3].set_title('Global')
ax[3].plot(freqs,psd6ND_1[3],label='Run 1',color='red',linewidth=1)
ax[3].plot(freqs,psd6ND_2[3],label='Run 2',color='blue',linewidth=1)
ax[0].set_ylabel('PSD')
ax[0].set_xlabel('Frequency (Hz)')
ax[1].set_xlabel('Frequency (Hz)')
ax[2].set_xlabel('Frequency (Hz)')
ax[3].set_xlabel('Frequency (Hz)')
ax[0].set_ylim([0,17])
ax[1].set_ylim([0,17])
ax[2].set_ylim([0,17])
ax[3].set_ylim([0,17])
ax[0].set_xlim([0,50])
ax[1].set_xlim([0,50])
ax[2].set_xlim([0,50])
ax[3].set_xlim([0,50])
ax[0].set_xticks(np.arange(0, 50, 5))
ax[1].set_xticks(np.arange(0, 50, 5))
ax[2].set_xticks(np.arange(0, 50, 5))
ax[3].set_xticks(np.arange(0, 50, 5))
ax[0].legend()
ax[1].legend()
ax[2].legend()
ax[3].legend()
 
fig,ax = plt.subplots(1,4,figsize=(30,6))
fig.suptitle('No Dementia | 12-months',fontsize=15)
ax[0].set_title('Fz')
ax[0].plot(freqs,psd12ND_1[0],label='Run 1',color='red',linewidth=1)
ax[0].plot(freqs,psd12ND_2[0],label='Run 2',color='blue',linewidth=1)
ax[1].set_title('Cz')
ax[1].plot(freqs,psd12ND_1[1],label='Run 1',color='red',linewidth=1)
ax[1].plot(freqs,psd12ND_2[1],label='Run 2',color='blue',linewidth=1)
ax[2].set_title('Pz')
ax[2].plot(freqs,psd12ND_1[2],label='Run 1',color='red',linewidth=1)
ax[2].plot(freqs,psd12ND_2[2],label='Run 2',color='blue',linewidth=1)
ax[3].set_title('Global')
ax[3].plot(freqs,psd12ND_1[3],label='Run 1',color='red',linewidth=1)
ax[3].plot(freqs,psd12ND_2[3],label='Run 2',color='blue',linewidth=1)
ax[0].set_ylabel('PSD')
ax[0].set_xlabel('Frequency (Hz)')
ax[1].set_xlabel('Frequency (Hz)')
ax[2].set_xlabel('Frequency (Hz)')
ax[3].set_xlabel('Frequency (Hz)')
ax[0].set_ylim([0,17])
ax[1].set_ylim([0,17])
ax[2].set_ylim([0,17])
ax[3].set_ylim([0,17])
ax[0].set_xlim([0,50])
ax[1].set_xlim([0,50])
ax[2].set_xlim([0,50])
ax[3].set_xlim([0,50])
ax[0].set_xticks(np.arange(0, 50, 5))
ax[1].set_xticks(np.arange(0, 50, 5))
ax[2].set_xticks(np.arange(0, 50, 5))
ax[3].set_xticks(np.arange(0, 50, 5))
ax[0].legend()
ax[1].legend()
ax[2].legend()
ax[3].legend()

# %% [markdown]
# Mild-Moderate Dementia across TimePoints

# %%
fig,ax = plt.subplots(1,4,figsize=(30,6))
fig.suptitle('Mild-Moderate Dementia | Baseline',fontsize=15)
ax[0].set_title('Fz')
ax[0].plot(freqs,psdBMMD_1[0],label='Run 1',color='red',linewidth=1)
ax[0].plot(freqs,psdBMMD_2[0],label='Run 2',color='blue',linewidth=1)
ax[1].set_title('Cz')
ax[1].plot(freqs,psdBMMD_1[1],label='Run 1',color='red',linewidth=1)
ax[1].plot(freqs,psdBMMD_2[1],label='Run 2',color='blue',linewidth=1)
ax[2].set_title('Pz')
ax[2].plot(freqs,psdBMMD_1[2],label='Run 1',color='red',linewidth=1)
ax[2].plot(freqs,psdBMMD_2[2],label='Run 2',color='blue',linewidth=1)
ax[3].set_title('Global')
ax[3].plot(freqs,psdBMMD_1[3],label='Run 1',color='red',linewidth=1)
ax[3].plot(freqs,psdBMMD_2[3],label='Run 2',color='blue',linewidth=1)
ax[0].set_ylabel('PSD')
ax[0].set_xlabel('Frequency (Hz)')
ax[1].set_xlabel('Frequency (Hz)')
ax[2].set_xlabel('Frequency (Hz)')
ax[3].set_xlabel('Frequency (Hz)')
ax[0].set_ylim([0,17])
ax[1].set_ylim([0,17])
ax[2].set_ylim([0,17])
ax[3].set_ylim([0,17])
ax[0].set_xlim([0,50])
ax[1].set_xlim([0,50])
ax[2].set_xlim([0,50])
ax[3].set_xlim([0,50])
ax[0].set_xticks(np.arange(0, 50, 5))
ax[1].set_xticks(np.arange(0, 50, 5))
ax[2].set_xticks(np.arange(0, 50, 5))
ax[3].set_xticks(np.arange(0, 50, 5))
ax[0].legend()
ax[1].legend()
ax[2].legend()
ax[3].legend()

fig,ax = plt.subplots(1,4,figsize=(30,6))
fig.suptitle('Mild-Moderate Dementia | 6-months',fontsize=15)
ax[0].set_title('Fz')
ax[0].plot(freqs,psd6MMD_1[0],label='Run 1',color='red',linewidth=1)
ax[0].plot(freqs,psd6MMD_2[0],label='Run 2',color='blue',linewidth=1)
ax[1].set_title('Cz')
ax[1].plot(freqs,psd6MMD_1[1],label='Run 1',color='red',linewidth=1)
ax[1].plot(freqs,psd6MMD_2[1],label='Run 2',color='blue',linewidth=1)
ax[2].set_title('Pz')
ax[2].plot(freqs,psd6MMD_1[2],label='Run 1',color='red',linewidth=1)
ax[2].plot(freqs,psd6MMD_2[2],label='Run 2',color='blue',linewidth=1)
ax[3].set_title('Global')
ax[3].plot(freqs,psd6MMD_1[3],label='Run 1',color='red',linewidth=1)
ax[3].plot(freqs,psd6MMD_2[3],label='Run 2',color='blue',linewidth=1)
ax[0].set_ylabel('PSD')
ax[0].set_xlabel('Frequency (Hz)')
ax[1].set_xlabel('Frequency (Hz)')
ax[2].set_xlabel('Frequency (Hz)')
ax[3].set_xlabel('Frequency (Hz)')
ax[0].set_ylim([0,17])
ax[1].set_ylim([0,17])
ax[2].set_ylim([0,17])
ax[3].set_ylim([0,17])
ax[0].set_xlim([0,50])
ax[1].set_xlim([0,50])
ax[2].set_xlim([0,50])
ax[3].set_xlim([0,50])
ax[0].set_xticks(np.arange(0, 50, 5))
ax[1].set_xticks(np.arange(0, 50, 5))
ax[2].set_xticks(np.arange(0, 50, 5))
ax[3].set_xticks(np.arange(0, 50, 5))
ax[0].legend()
ax[1].legend()
ax[2].legend()
ax[3].legend()

fig,ax = plt.subplots(1,4,figsize=(30,6))
fig.suptitle('Mild-Moderate Dementia | 12-months',fontsize=15)
ax[0].set_title('Fz')
ax[0].plot(freqs,psd12MMD_1[0],label='Run 1',color='red',linewidth=1)
ax[0].plot(freqs,psd12MMD_2[0],label='Run 2',color='blue',linewidth=1)
ax[1].set_title('Cz')
ax[1].plot(freqs,psd12MMD_1[1],label='Run 1',color='red',linewidth=1)
ax[1].plot(freqs,psd12MMD_2[1],label='Run 2',color='blue',linewidth=1)
ax[2].set_title('Pz')
ax[2].plot(freqs,psd12MMD_1[2],label='Run 1',color='red',linewidth=1)
ax[2].plot(freqs,psd12MMD_2[2],label='Run 2',color='blue',linewidth=1)
ax[3].set_title('Global')
ax[3].plot(freqs,psd12MMD_1[3],label='Run 1',color='red',linewidth=1)
ax[3].plot(freqs,psd12MMD_2[3],label='Run 2',color='blue',linewidth=1)
ax[0].set_ylabel('PSD')
ax[0].set_xlabel('Frequency (Hz)')
ax[1].set_xlabel('Frequency (Hz)')
ax[2].set_xlabel('Frequency (Hz)')
ax[3].set_xlabel('Frequency (Hz)')
ax[0].set_ylim([0,17])
ax[1].set_ylim([0,17])
ax[2].set_ylim([0,17])
ax[3].set_ylim([0,17])
ax[0].set_xlim([0,50])
ax[1].set_xlim([0,50])
ax[2].set_xlim([0,50])
ax[3].set_xlim([0,50])
ax[0].set_xticks(np.arange(0, 50, 5))
ax[1].set_xticks(np.arange(0, 50, 5))
ax[2].set_xticks(np.arange(0, 50, 5))
ax[3].set_xticks(np.arange(0, 50, 5))
ax[0].legend()
ax[1].legend()
ax[2].legend()
ax[3].legend()

# %% [markdown]
# Severe Dementia across TimePoints

# %%
fig,ax = plt.subplots(1,4,figsize=(30,6))
fig.suptitle('Severe Dementia | Baseline',fontsize=15)
ax[0].set_title('Fz')
ax[0].plot(freqs,psdBSD_1[0],label='Run 1',color='red',linewidth=1)
ax[0].plot(freqs,psdBSD_2[0],label='Run 2',color='blue',linewidth=1)
ax[1].set_title('Cz')
ax[1].plot(freqs,psdBSD_1[1],label='Run 1',color='red',linewidth=1)
ax[1].plot(freqs,psdBSD_2[1],label='Run 2',color='blue',linewidth=1)
ax[2].set_title('Pz')
ax[2].plot(freqs,psdBSD_1[2],label='Run 1',color='red',linewidth=1)
ax[2].plot(freqs,psdBSD_2[2],label='Run 2',color='blue',linewidth=1)
ax[3].set_title('Global')
ax[3].plot(freqs,psdBSD_1[3],label='Run 1',color='red',linewidth=1)
ax[3].plot(freqs,psdBSD_2[3],label='Run 2',color='blue',linewidth=1)
ax[0].set_ylabel('PSD')
ax[0].set_xlabel('Frequency (Hz)')
ax[1].set_xlabel('Frequency (Hz)')
ax[2].set_xlabel('Frequency (Hz)')
ax[3].set_xlabel('Frequency (Hz)')
ax[0].set_ylim([0,17])
ax[1].set_ylim([0,17])
ax[2].set_ylim([0,17])
ax[3].set_ylim([0,17])
ax[0].set_xlim([0,50])
ax[1].set_xlim([0,50])
ax[2].set_xlim([0,50])
ax[3].set_xlim([0,50])
ax[0].set_xticks(np.arange(0, 50, 5))
ax[1].set_xticks(np.arange(0, 50, 5))
ax[2].set_xticks(np.arange(0, 50, 5))
ax[3].set_xticks(np.arange(0, 50, 5))
ax[0].legend()
ax[1].legend()
ax[2].legend()
ax[3].legend()

fig,ax = plt.subplots(1,4,figsize=(30,6))
fig.suptitle('Severe Dementia | 6-months',fontsize=15)
ax[0].set_title('Fz')
ax[0].plot(freqs,psd6SD_1[0],label='Run 1',color='red',linewidth=1)
ax[0].plot(freqs,psd6SD_2[0],label='Run 2',color='blue',linewidth=1)
ax[1].set_title('Cz')
ax[1].plot(freqs,psd6SD_1[1],label='Run 1',color='red',linewidth=1)
ax[1].plot(freqs,psd6SD_2[1],label='Run 2',color='blue',linewidth=1)
ax[2].set_title('Pz')
ax[2].plot(freqs,psd6SD_1[2],label='Run 1',color='red',linewidth=1)
ax[2].plot(freqs,psd6SD_2[2],label='Run 2',color='blue',linewidth=1)
ax[3].set_title('Global')
ax[3].plot(freqs,psd6SD_1[3],label='Run 1',color='red',linewidth=1)
ax[3].plot(freqs,psd6SD_2[3],label='Run 2',color='blue',linewidth=1)
ax[0].set_ylabel('PSD')
ax[0].set_xlabel('Frequency (Hz)')
ax[1].set_xlabel('Frequency (Hz)')
ax[2].set_xlabel('Frequency (Hz)')
ax[3].set_xlabel('Frequency (Hz)')
ax[0].set_ylim([0,17])
ax[1].set_ylim([0,17])
ax[2].set_ylim([0,17])
ax[3].set_ylim([0,17])
ax[0].set_xlim([0,50])
ax[1].set_xlim([0,50])
ax[2].set_xlim([0,50])
ax[3].set_xlim([0,50])
ax[0].set_xticks(np.arange(0, 50, 5))
ax[1].set_xticks(np.arange(0, 50, 5))
ax[2].set_xticks(np.arange(0, 50, 5))
ax[3].set_xticks(np.arange(0, 50, 5))
ax[0].legend()
ax[1].legend()
ax[2].legend()
ax[3].legend()

fig,ax = plt.subplots(1,4,figsize=(30,6))
fig.suptitle('Severe Dementia | 12-months',fontsize=15)
ax[0].set_title('Fz')
ax[0].plot(freqs,psd12SD_1[0],label='Run 1',color='red',linewidth=1)
ax[0].plot(freqs,psd12SD_2[0],label='Run 2',color='blue',linewidth=1)
ax[1].set_title('Cz')
ax[1].plot(freqs,psd12SD_1[1],label='Run 1',color='red',linewidth=1)
ax[1].plot(freqs,psd12SD_2[1],label='Run 2',color='blue',linewidth=1)
ax[2].set_title('Pz')
ax[2].plot(freqs,psd12SD_1[2],label='Run 1',color='red',linewidth=1)
ax[2].plot(freqs,psd12SD_2[2],label='Run 2',color='blue',linewidth=1)
ax[3].set_title('Global')
ax[3].plot(freqs,psd12SD_1[3],label='Run 1',color='red',linewidth=1)
ax[3].plot(freqs,psd12SD_2[3],label='Run 2',color='blue',linewidth=1)
ax[0].set_ylabel('PSD')
ax[0].set_xlabel('Frequency (Hz)')
ax[1].set_xlabel('Frequency (Hz)')
ax[2].set_xlabel('Frequency (Hz)')
ax[3].set_xlabel('Frequency (Hz)')
ax[0].set_ylim([0,17])
ax[1].set_ylim([0,17])
ax[2].set_ylim([0,17])
ax[3].set_ylim([0,17])
ax[0].set_xlim([0,50])
ax[1].set_xlim([0,50])
ax[2].set_xlim([0,50])
ax[3].set_xlim([0,50])
ax[0].set_xticks(np.arange(0, 50, 5))
ax[1].set_xticks(np.arange(0, 50, 5))
ax[2].set_xticks(np.arange(0, 50, 5))
ax[3].set_xticks(np.arange(0, 50, 5))
ax[0].legend()
ax[1].legend()
ax[2].legend()
ax[3].legend()
